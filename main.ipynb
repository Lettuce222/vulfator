# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# 画像を読み込む。
filename = "data/input/woman.jpg"
img = cv.imread(filename)
plt.imshow(cv.cvtColor(img, cv.COLOR_BGR2RGB))
